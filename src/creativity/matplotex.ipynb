# %%
# The Figure-8 Curve

import numpy as np
import matplotlib.pyplot as plot

t = np.linspace(0, 2*np.pi, 100)

x = np.sin(t)
y = np.sin(t)*np.cos(t)

plot.plot(x, y, c=(1, 0.2, 0.5), lw=2)
plot.title('The Figure-8 Curve')
plot.axis('off')
plot.show()

# %%
# The Trefoil Knot

import numpy as np
import matplotlib.pyplot as plot

t = np.linspace(0, 2*np.pi, 100)

x = np.sin(t) + 2*np.sin(2*t)
y = np.cos(t) - 2*np.cos(2*t)

plot.title('The Trefoil Knot')
plot.plot(x, y, c=(1, 0.2, 0.5), lw=2)
plot.axis('off')
plot.show()

# %%
# The Butterfly Curve

import numpy as np
import matplotlib.pyplot as plot

t = np.linspace(0, 100, 1000)

x = np.sin(t)*(np.exp(np.cos(t)) - 2*np.cos(4*t) - np.sin(t/12)**5)
y = np.cos(t)*(np.exp(np.cos(t)) - 2*np.cos(4*t) - np.sin(t/12)**5)

plot.title('The Butterfly Curve')
plot.plot(x, y, c=(1, 0.2, 0.5), lw=0.5)
plot.axis('off')
plot.show()

# %%
# The Butterfly Curve

import numpy as np
import matplotlib.pyplot as plot

t = np.linspace(-3, 3, 10000)

x = 7*np.cos(np.cos(2.76*np.round(t)))**2 * (1 + np.cos(2.76*t)**4)
y = 7*np.sin(np.cos(2.76*t))**2 * np.sin(np.sin(2.6*t))

plot.title('The Unknown')
plot.plot(x, y, c=(1, 0.2, 0.5), lw=2)
plot.axis('off')
plot.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


def lorenz(xyz, *, s=10, r=28, b=2.667):
    """
    Parameters
    ----------
    xyz : array-like, shape (3,)
       Point of interest in three-dimensional space.
    s, r, b : float
       Parameters defining the Lorenz attractor.

    Returns
    -------
    xyz_dot : array, shape (3,)
       Values of the Lorenz attractor's partial derivatives at *xyz*.
    """
    x, y, z = xyz
    x_dot = s*(y - x)
    y_dot = r*x - y - x*z
    z_dot = x*y - b*z
    return np.array([x_dot, y_dot, z_dot])


dt = 0.01
num_steps = 10000

xyzs = np.empty((num_steps + 1, 3))  # Need one more for the initial values
xyzs[0] = (0., 1., 1.05)  # Set initial values
# Step through "time", calculating the partial derivatives at the current point
# and using them to estimate the next point
for i in range(num_steps):
    xyzs[i + 1] = xyzs[i] + lorenz(xyzs[i]) * dt

# Plot
ax = plt.figure().add_subplot(projection='3d')

ax.plot(*xyzs.T, lw=0.5)
ax.set_xlabel("X Axis")
ax.set_ylabel("Y Axis")
ax.set_zlabel("Z Axis")
ax.set_title("Lorenz Attractor")

plt.show()
