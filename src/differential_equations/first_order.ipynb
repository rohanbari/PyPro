# %% [markdown]
# # First Order Equations

# %%
import numpy as np
import matplotlib.pyplot as mpl

t = np.linspace(0, 10, 100)
for y_0 in range(-3, +3 + 1):
    c = y_0 - 0.5
    y = c * np.exp(-t) + (np.sin(t) + np.cos(t)) / 2
    mpl.plot(t, y, 'b')

mpl.title("y' + y = cos(t)")
mpl.show()
